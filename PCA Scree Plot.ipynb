# %%
cov_mat = [[0.28, 18752.86, 1.38, 359998.12, -0.03],
          [18752.86, 28051337061.44, 1186523.54, 438826234166.99, 9941.44],
          [1.38, 1186523.54, 511.59, 23667170.12, 4.49],
          [359998.12, 438826234166.99, 23667170.12, 12594802560308.30, 186185.04],
          [-0.03, 9941.44, 4.49, 186185.04, 0.71]]

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
u, s, v = np.linalg.svd(cov_mat)
eigvals = s**2 / np.cumsum(s)[-1]

# %%
fig = plt.figure(figsize = (25,18))
sing_vals = np.arange(5) + 1
plt.plot(sing_vals, eig_vals, 'ro-', linewidth = 2)
plt.title('Scree Plot')
plt.xlabel('PC')
plt.ylabel('Eigenvalue')

leg = plt.legend(['Eigenvalues from SVD'], loc = 'best', borderpad = 0.3,
                 shadow = False, prop = matplotlib.font_manager.FontProperties(size = 'small'),
                 markerscale = 0.4)
leg.get_frame().set_alpha(0.4)
leg.draggable(state = True)
plt.show()

# %%
fig.savefig('test.png')
